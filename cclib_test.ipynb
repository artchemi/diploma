# %%
import cclib

# %%
filename = '/home/daniil_artamonov/hpc4_kurchatov/diploma_gaussian/mc1_acetone/mc1_s1_b3lyp.log'
filename_gs = '/home/daniil_artamonov/hpc4_kurchatov/diploma_gaussian/mc1_acetone/mc1_gs_b3lyp.log'

# %%
parser = cclib.io.ccopen(filename)
parser_gs = cclib.io.ccopen(filename_gs)
data_gs = parser_gs.parse()
data = parser.parse()

# %%
data_gs.homos
# Out:
# array([84], dtype=int32)

# %%
data_gs.moenergies[0][85] - data.moenergies[0][86] - data_gs.moenergies[0][86]
# Out:
# 0.24735149010450008

# %%
(data.moenergies[0][0] - data.moenergies[0][85]) - (data_gs.moenergies[0][0] - data_gs.moenergies[0][84])
# Out:
# -4.987574765814429

# %%
print(data_gs.moenergies[0][84])
print(data.moenergies[0][85])
# Out:
# -7.001217259514501
# -2.0754123377635003

# %%
print(data.scfenergies[-1] - data_gs.scfenergies[-1])
# Out:
# 0.621421774449118

# %%
data.etenergies
# Out:
# array([14591.37617504, 24524.09396817, 27263.95936349, 28293.12281489,
#        34485.04116632])

# %%
data.etoscs
# Out:
# array([0.1596, 0.0895, 0.3592, 0.5542, 0.002 ])

# %%
data.e
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.e
#
# AttributeError: 'ccData_optdone_bool' object has no attribute 'e'

# %%
data.moenergies
# Out:
# [array([-5.34801405e+02, -5.34780997e+02, -5.32868036e+02, -4.07924785e+02,
#         -4.03951106e+02, -2.89788734e+02, -2.88756878e+02, -2.88429797e+02,
#         -2.88209657e+02, -2.88196323e+02, -2.88103532e+02, -2.87951693e+02,
#         -2.87599033e+02, -2.87477671e+02, -2.87414812e+02, -2.87399302e+02,
#         -2.87391138e+02, -2.87305150e+02, -2.87239843e+02, -2.87170726e+02,
#         -2.87091269e+02, -2.87070316e+02, -2.86727453e+02, -2.86723643e+02,
#         -3.71470781e+01, -3.20136503e+01, -3.11189399e+01, -3.08076417e+01,
#         -2.67662068e+01, -2.66249797e+01, -2.60848337e+01, -2.52418250e+01,
#         -2.38581261e+01, -2.36774425e+01, -2.34880512e+01, -2.32894081e+01,
#         -2.24736108e+01, -2.16605346e+01, -2.10292305e+01, -2.04507164e+01,
#         -2.00849954e+01, -1.93992685e+01, -1.88444284e+01, -1.84142164e+01,
#         -1.80835980e+01, -1.77899872e+01, -1.70384087e+01, -1.69986801e+01,
# ...
